# %%
import requests
import pandas as pd
import time
from requests.structures import CaseInsensitiveDict
import warnings
warnings.filterwarnings("ignore")
from datetime import datetime
import psycopg2 as ps

# %%
#Keys
CLIENT_ID = 'xxx'
SECRET_KEY = 'xxx'
ACCESS_TOKEN = 'xxx'

# %%
def get_data(df):
    
    #stack api connection variables to get 100 most viewed streams at the moment
    url = 'https://api.twitch.tv/helix/streams?first=100'
    headers = CaseInsensitiveDict()
    headers["Authorization"] = f"Bearer {ACCESS_TOKEN}"
    headers["Client-Id"] = CLIENT_ID

    
    resp = requests.get(url, headers=headers).json()
    
    #loop for each json collection - append everything to a pd dataframe
    time.sleep(1)
    for stream in resp['data']:
        user_name = stream['user_name']
        game_name = stream['game_name']
        transmission_type = stream['type']
        title = stream['title']
        viewer_count = stream['viewer_count']
        started_at = stream['started_at']
        started_at = datetime.strptime(started_at, "%Y-%m-%dT%H:%M:%S%z")
        language = stream['language']
        is_mature = stream['is_mature']

        df = df.append(
            {'user_name': user_name,
             'game_name': game_name,
             'type': transmission_type,
             'title': title,
             'viewer_count': viewer_count,
             'started_at': started_at,
             'language': language,
             'is_mature': is_mature},
            ignore_index = True
        )
        
    return df

# %%
#create an empty df for right columns
df = pd.DataFrame(columns=[
        'user_name',
        'game_name',
        'type',
        'title',
        'viewer_count',
        'started_at',
        'language',
        'is_mature'
    ])

#get streaming data and append it to the empty df
df = get_data(df)

# %%
df
# Out:
#          user_name                                     game_name  type  \
# 0             ibai                                 Just Chatting  live
# 1         HasanAbi                                 Just Chatting  live
# 2     ElisaEsports              Counter-Strike: Global Offensive  live
# 3          Elraenn                                      Grounded  live
# 4           Nmplol                             World of Warcraft  live
# ..             ...                                           ...   ...
# 94      ungespielt                             World of Warcraft  live
# 95  Cydonia_Chiara                        Pokémon Scarlet/Violet  live
# 96             Ray                        Pokémon Scarlet/Violet  live
# 97        VooDooSh  The Dark Pictures Anthology: The Devil in Me  live
# 98       akaNemsko                                 Just Chatting  live
#
#                                                 title viewer_count  \
# 0   LUIS ENRIQUE DEBUTA COMO STREAMER EL SELECCION...        48441
# 1   TWITTER IS ACTUALLY IMPLODING!!!!! OKBUDDYFRIDAY!        40382
# 2   ENCE vs. Astralis | Quarter-Finals | Elisa Mas...        30312
# 3                                               yayak        27891
# 4   [DROPS] OTK WORLD OF WARCRAFT 3v3 DRAFT INVITA...        26280
# ..                                                ...          ...
# 94  DROPS AKTIV! - !Subathon - #ungeklickt & WoW !...         4506
# 95  BLIND RUN Pokémon Scarlatto e Violetto #2: "Me...         4495
# 96  !giveaway !store | POKEMON SCARLET/VIOLET IS H...         4494
# 97  Новый Кино-Хоррор от Dark Pictures! The Devil ...         4442
# 98  !FLEX FRIDAY ~ come flex your games | !socials...         4427
#
#                   started_at language is_mature
# 0  2022-11-18 18:23:07+00:00       es     False
# 1  2022-11-18 19:34:55+00:00       en     False
# 2  2022-11-18 13:43:42+00:00       en     False
# 3  2022-11-18 17:13:47+00:00       tr      True
# 4  2022-11-18 16:01:56+00:00       en     False
# ..                       ...      ...       ...
# 94 2022-11-18 19:03:00+00:00       de     False
# 95 2022-11-18 13:59:29+00:00       it     False
# 96 2022-11-18 17:45:19+00:00       en     False
# 97 2022-11-18 20:14:37+00:00       ru     False
# 98 2022-11-18 19:02:07+00:00       en     False
#
# [99 rows x 8 columns]

# %%
### Database connection section

# %%
# Check if we connected succesfully to the cloud db
def connect_to_db(host_name, dbname, port, username, password):
    try:
        conn = ps.connect(host=host_name, database=dbname, user=username, password=password, port=port)
        
    except ps.OperationalError as e:
        raise e
    else:
            print('Connected')
    return conn

# %%
# Create table in the cloud db

def create_table(curr):
    create_table_command = ("""CREATE TABLE IF NOT EXISTS stream (
                        user_name varchar(255) not null,
                        game_name varchar(255) not null,
                        type varchar(10) not null,
                        title varchar(225) not null,
                        viewer_count integer not null,
                        started_at date not null,
                        language varchar(2) not null,
                        is_mature varchar(10) not null
                        )""")
    curr.execute(create_table_command)

# %%
# insert data into postgres table
def insert_into_table(curr, user_name, game_name, type, title, viewer_count, started_at, language, is_mature):
    insert_into_streams = ("""INSERT INTO stream (user_name, game_name, type, title, viewer_count, started_at, language, is_mature)
        VALUES(%s, %s, %s, %s, %s, %s, %s, %s);""")

    row_to_insert = (user_name, game_name, type, title, viewer_count, started_at, language, is_mature)

    curr.execute(insert_into_streams, row_to_insert)

# %%
#Push data from pandas dataframe to the newly connected db 
def append_from_df_to_db(curr, df):
    for i, row in df.iterrows():
        insert_into_table(curr, row['user_name'],
                                row['game_name'],
                                row['type'],
                                row['title'],
                                row['viewer_count'],
                                row['started_at'],
                                row['language'],
                                row['is_mature'])

# %%
# DB connection variables
host_name = 'database-project-twitch.xxx'
dbname = 'x'
port = '5432'
username = 'postgres'
password = 'x'
conn = None

conn = connect_to_db(host_name, dbname, port, username, password)
# Out:
# Connected

# %%
curr = conn.cursor()

# %%
create_table(curr)

# %%
append_from_df_to_db(curr, df)

# %%
conn.commit()

# %%
#If no results then failed, else data pushed successfully

curr.fetchall()
# Out:
# [('HasanAbi',
#   'Just Chatting',
#   'live',
#   'TWITTER IS ACTUALLY IMPLODING!!!!! OKBUDDYFRIDAY!',
#   40382,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('ElisaEsports',
#   'Counter-Strike: Global Offensive',
#   'live',
#   'ENCE vs. Astralis | Quarter-Finals | Elisa Masters Espoo 2022',
#   30312,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('Elraenn',
#   'Grounded',
#   'live',
#   'yayak',
#   27891,
#   datetime.date(2022, 11, 18),
#   'tr',
#   'true'),
#  ('Nmplol',
#   'World of Warcraft',
#   'live',
#   '[DROPS] OTK WORLD OF WARCRAFT 3v3 DRAFT INVITATIONAL FT ASMONGOLD SODAPOPPIN & NMPLOL',
#   26280,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('GRONKH',
#   'Just Chatting',
#   'live',
#   '#FREiAB18 // !horde2 !ff8',
#   25356,
#   datetime.date(2022, 11, 18),
#   'de',
#   'true'),
#  ('LIRIK',
#   'Warhammer 40,000: Darktide',
#   'live',
#   'Me Smash',
#   24970,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('juansguarnizo',
#   'Goat Simulator 3',
#   'live',
#   'VIERNES TRAVIESO +18 PARA ADULTOS 😈😈😈',
#   23119,
#   datetime.date(2022, 11, 18),
#   'es',
#   'false'),
#  ('Rubius',
#   'Pokémon Scarlet/Violet',
#   'live',
#   '🫒ESTRENO DE POKEMON ESPAÑITA🫒NUEVO VIDEO EN elrubiusOMG🫒NUEVO SETUP DE GIGACHAD🫒MAÑANA PARTIDO VS FRANCIA🫒',
#   21907,
#   datetime.date(2022, 11, 18),
#   'es',
#   'false'),
#  ('Fextralife',
#   'Overwatch 2',
#   'live',
#   '!DROPS ENABLED !OW2 with CAS! #Overwatch2_Sponsored',
#   18743,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('Symfuhny',
#   'Call of Duty: Warzone',
#   'live',
#   '28 WINS | GOIN FOR A NUKE ON WARZONE 2! WINNING EVERY GAME!',
#   18674,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('Castro_1021',
#   'FIFA 23',
#   'live',
#   '2 DAYS TILL WORLD CUP!! @Castro1021',
#   18126,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('alanzoka',
#   'The Dark Pictures Anthology: The Devil in Me',
#   'live',
#   'AS AVENTURAS DE UM BLOGUEIRINHO',
#   16814,
#   datetime.date(2022, 11, 18),
#   'pt',
#   'false'),
#  ('knekro',
#   'Pokémon Scarlet/Violet',
#   'live',
#   'ESPECIAL POKEMON PURPURA | DIA 1 |  El inicio de una aventura epica | !sorteosubs',
#   16676,
#   datetime.date(2022, 11, 18),
#   'es',
#   'false'),
#  ('shroud',
#   'Overwatch 2',
#   'live',
#   'Gaming with the homies !Overwatch #Overwatch2_Sponsored !maingear | @shroud on socials',
#   16333,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('Brawlhalla',
#   'PlateUp!',
#   'live',
#   'Charity Stream: Benefitting One Tree Planted',
#   16316,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('NoWay4u_Sir',
#   'League of Legends',
#   'live',
#   'PRESEASON SUPER FUN TIME',
#   15556,
#   datetime.date(2022, 11, 18),
#   'de',
#   'false'),
#  ('BagginsTV',
#   'New World',
#   'live',
#   'ALL !DROPS ON ✅ Last day of RTA!',
#   14243,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('AntoineDaniel',
#   'Pokémon Scarlet/Violet',
#   'live',
#   "POKÉMON VIOLET | JE N'AI RIEN VU DU JEU, JE CONNAIS MÊME PAS LES STARTERS, VAIS-JE FAIRE PLUS D'UN STREAM DESSUS ?????",
#   13855,
#   datetime.date(2022, 11, 18),
#   'fr',
#   'true'),
#  ('JLTomy',
#   'Grand Theft Auto V',
#   'live',
#   'Reese Kronos : Prise de service !',
#   13455,
#   datetime.date(2022, 11, 18),
#   'fr',
#   'true'),
#  ('chowh1',
#   'Call of Duty: Warzone',
#   'live',
#   '🔥 SUBATHONH1 - JOUR 3 🔥 !Promos',
#   13256,
#   datetime.date(2022, 11, 17),
#   'fr',
#   'true'),
#  ('Gaules',
#   'FIFA 23',
#   'live',
#   'SEXTOU CO S DE MULA  - !vote - Siga @gaules nas redes sociais',
#   12916,
#   datetime.date(2022, 11, 18),
#   'pt',
#   'true'),
#  ('loltyler1',
#   'Overwatch 2',
#   'live',
#   'SPECIAL TALENTED POWER UP ! GAH ! darn ! NO WORKS ! try again again and also .  ok .. DID IT ! LEVEL RAISE PROMOTE ! #Overwatch2_Sponsored',
#   12819,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('Tumblurr',
#   'The Dark Pictures Anthology: The Devil in Me',
#   'live',
#   '[HORROR A SCELTE] MAN OF MEDAN NUOVO | !indirizzo !levlup !instagram !discord !social !waitingroom',
#   12357,
#   datetime.date(2022, 11, 18),
#   'it',
#   'false'),
#  ('pokimane',
#   'Overwatch 2',
#   'live',
#   '100% DROP RATE ✔️ OVERWATCH ADDICT 🔴 DPS MAIN - PHARAH / SOLDIER76 - #Overwatch2_Sponsored :)',
#   11895,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('Eray',
#   'Grand Theft Auto V',
#   'live',
#   'yeni düzen',
#   11625,
#   datetime.date(2022, 11, 18),
#   'tr',
#   'true'),
#  ('EWROON',
#   'Grand Theft Auto V',
#   'live',
#   'GTA RP PASTOR ZPASTOREM TWOJE 5 SEKUND | ODBIERZ DARMOWEGO SUBA TUTAJ !prime',
#   11021,
#   datetime.date(2022, 11, 18),
#   'pl',
#   'false'),
#  ('Wirtual',
#   'Trackmania',
#   'live',
#   'The Hardest Trackmania Tower Map DAY 2 - FLOOR 7/15',
#   11018,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('Recrent',
#   'Counter-Strike: Global Offensive',
#   'live',
#   'ТУРНИР 10 МИЛЛИОНОВ EML MEDIA LEAGUE w/ Boombl4, Dava, Pokanoname, Супер Стас',
#   10866,
#   datetime.date(2022, 11, 18),
#   'ru',
#   'false'),
#  ('forsen',
#   'The Dark Pictures Anthology: The Devil in Me',
#   'live',
#   'Games and shit!',
#   10840,
#   datetime.date(2022, 11, 18),
#   'en',
#   'true'),
#  ('Tfue',
#   'Fortnite',
#   'live',
#   'Duo Tournament Cups all day!!!',
#   10662,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('BastiGHG',
#   'Minecraft',
#   'live',
#   'CRAFT ATTACK 10 - TAG 21',
#   10561,
#   datetime.date(2022, 11, 18),
#   'de',
#   'false'),
#  ('Stray228',
#   'Dota 2',
#   'live',
#   'Легендарная пятничная борьбэ с крепкими мужчинами в патче 7.32 на высоком рейтинге + телеграм тут https://t.me/StrayDungeon228',
#   10547,
#   datetime.date(2022, 11, 18),
#   'ru',
#   'false'),
#  ('Jahrein',
#   'Just Chatting',
#   'live',
#   'Reddit Etkinliği!! - !itopya !grand',
#   10536,
#   datetime.date(2022, 11, 18),
#   'tr',
#   'false'),
#  ('GamerBrother',
#   'FIFA 23',
#   'live',
#   'XXL WM HERO Team 2 Pack Opening + WL mit R9 ölen 🔥 | !fm23 !prime !tno',
#   10219,
#   datetime.date(2022, 11, 18),
#   'de',
#   'false'),
#  ('VALORANT',
#   'VALORANT',
#   'live',
#   '(Rebroadcast) VALORANT Game Changers Championship - Day 4',
#   9884,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('NICKMERCS',
#   'Apex Legends',
#   'live',
#   "Warmin' Up For Pro Scrims! | Code: MFAM | @NICKMERCS",
#   9631,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('cloakzy',
#   'Call of Duty: Warzone',
#   'live',
#   'WARZONE 2 OP GUNS 10+KD +40 WINS ALREADY',
#   9609,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('SmallAnt',
#   'Pokémon Scarlet/Violet',
#   'live',
#   '12 HOUR STREAMS TILL I FINISH THE POKEDEX',
#   9587,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('Kyedae',
#   'VALORANT',
#   'live',
#   'GOOD MORNING!!!!',
#   9449,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('Elajjaz',
#   'The Dark Pictures Anthology: The Devil in Me',
#   'live',
#   'The Devil in Me 😈 New Horror game',
#   9319,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('gabepeixe',
#   'Just Chatting',
#   'live',
#   'SEXTOU! TDC',
#   9251,
#   datetime.date(2022, 11, 18),
#   'pt',
#   'false'),
#  ('JesusAVGN',
#   'Just Chatting',
#   'live',
#   '!VPN || ХМММ - https://t.me/jesusavgntwitch',
#   8900,
#   datetime.date(2022, 11, 18),
#   'ru',
#   'false'),
#  ('Joueur_du_Grenier',
#   'Ghostbusters: Spirits Unleashed',
#   'live',
#   "Qui qui c'est qu'on appelle ? (avec Seb Karim et Panda)",
#   8892,
#   datetime.date(2022, 11, 18),
#   'fr',
#   'false'),
#  ('A_Seagull',
#   'Overwatch 2',
#   'live',
#   '[DROPS ENABLED]  REACTING TO BLOG POST + PATCH NOTES',
#   8551,
#   datetime.date(2022, 11, 18),
#   'en',
#   'true'),
#  ('ChristianVieriOfficial',
#   'Sports',
#   'live',
#   'BoboTV | Calcio con la F',
#   8283,
#   datetime.date(2022, 11, 18),
#   'it',
#   'false'),
#  ('veibae',
#   'Bloodborne',
#   'live',
#   '🩸 Bloodborne continues 🩸 weebs welcome | !fakku !tts !socials',
#   8095,
#   datetime.date(2022, 11, 18),
#   'en',
#   'true'),
#  ('Towelliee',
#   'World of Warcraft',
#   'live',
#   '🐉!DROPS [LAST DAY] DRAGON KITE PET TCG🐉Watch 4 Hours!🐉DF BETA M+ BURRRR🐉ADV CODE "TOWEL" 🐉!ORIGIN !GUNNAR🐉',
#   8071,
#   datetime.date(2022, 11, 17),
#   'en',
#   'false'),
#  ('QuickyBaby',
#   'World of Tanks',
#   'live',
#   '🤩*NEW* !DROPS🤩 | GET !QUICKYBABY IN WOT | 30 x !PollTanks @19:00 | NEW !BestMoments | !Prime Loot | 18/11/2022',
#   7898,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('Noni',
#   'Minecraft',
#   'live',
#   'TORTILLALAND DIA 70',
#   7664,
#   datetime.date(2022, 11, 18),
#   'es',
#   'false'),
#  ('Bethesda',
#   'The Elder Scrolls Online',
#   'live',
#   'ESO Live at Home ft. Matthew K Heafy, Cristina Scabbia & Malukah #TavernsAndTales',
#   7640,
#   datetime.date(2022, 11, 18),
#   'en',
#   'true'),
#  ('artefr',
#   'Talk Shows & Podcasts',
#   'live',
#   '💿 Laser Disc avec Mister MV, Mynthos et Canblaster I Présenté par Pierre Lapin et Horty !discord !dedicaces !lieu',
#   7622,
#   datetime.date(2022, 11, 18),
#   'fr',
#   'false'),
#  ('mL7support',
#   'Overwatch 2',
#   'live',
#   '🔴 !DROPS ON 🔴 PATCH LIVE 🔴 SUPPORT NOT HEALER 🔴 !MERCH !VIDEO !VOD !TIERLIST 🔴',
#   7530,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('SmiteGame',
#   'SMITE',
#   'live',
#   'SMITE PRO LEAGUE: Valkyries vs Dragons (Phase 3: Week 7)',
#   7489,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('FolagorLives',
#   'Pokémon Scarlet/Violet',
#   'live',
#   '🌟123 HORAS🌟Pokémon Escarlata y Púrpura ESPECIAL | SORTEO NINTENDO SWITCH HOY PARA SUBS | Suscríbete GRATIS con TWITCH PRIME',
#   7483,
#   datetime.date(2022, 11, 17),
#   'es',
#   'false'),
#  ('elyoyalol',
#   'League of Legends',
#   'live',
#   'A EXPLORAR LA PRESEASON 🥱 / MAD Elyoya !yt !video !discord',
#   7421,
#   datetime.date(2022, 11, 18),
#   'es',
#   'false'),
#  ('follentass',
#   'Just Chatting',
#   'live',
#   '🚐ДРИФТ НА ВАННЕ🛁',
#   7386,
#   datetime.date(2022, 11, 18),
#   'ru',
#   'true'),
#  ('TheGrefg',
#   'God of War Ragnarök',
#   'live',
#   'NOS PREPARAMOS PARA EL FINAL DE GOW RAGNAROK *MÁXIMA DIFICULTAD* 😈 !ENTRADAS MUNDIAL ⚽🏆',
#   7269,
#   datetime.date(2022, 11, 18),
#   'es',
#   'false'),
#  ('pokelawls',
#   'Overwatch 2',
#   'live',
#   'NO WAY!! PLAYING OVERWATCH 2 !! #Overwatch2_Sponsored',
#   7207,
#   datetime.date(2022, 11, 18),
#   'en',
#   'true'),
#  ('Aydan',
#   'Call of Duty: Warzone',
#   'live',
#   'WZ 2.0 w/ MuTeX | !loadouts !twitter !tiktok',
#   7005,
#   datetime.date(2022, 11, 18),
#   'en',
#   'true'),
#  ('RocketBeansTV',
#   'Special Events',
#   'live',
#   'HAUS AN HAUS 3 - Rocket Beans vs. GameStar (24h-Gaming-Event)',
#   6874,
#   datetime.date(2022, 11, 18),
#   'de',
#   'false'),
#  ('samueletienne',
#   'Just Chatting',
#   'live',
#   "L'Hebdo Est Tienne : on revient avec 3 invités sur l'actu de la semaine",
#   6863,
#   datetime.date(2022, 11, 18),
#   'fr',
#   'false'),
#  ('DarioMocciaTwitch',
#   'Pokémon Scarlet/Violet',
#   'live',
#   'Aperitivo con Pokémon, Pub e poi Pokémon !prime !merch !posta !flashback !creator',
#   6746,
#   datetime.date(2022, 11, 18),
#   'it',
#   'false'),
#  ('Sardoche',
#   'League of Legends',
#   'live',
#   'SARDOCHE - CASSIO PRE-SAISON',
#   6570,
#   datetime.date(2022, 11, 18),
#   'fr',
#   'false'),
#  ('Pikabooirl',
#   'World of Warcraft',
#   'live',
#   'GG Pikaboo - !DROPS OTK TOURNY BABY',
#   6385,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('IamCristinini',
#   'Pokémon Scarlet/Violet',
#   'live',
#   '🔴 !SORTEO XBOX POKÉMON ESCARLATA 🎉 | !prime !sub | Follow @IamCristinini',
#   6303,
#   datetime.date(2022, 11, 18),
#   'es',
#   'false'),
#  ('bruxaofc',
#   'Virtual Casino',
#   'live',
#   'GRUPO VIP BLAZE DOUBLE',
#   6300,
#   datetime.date(2022, 11, 18),
#   'pt',
#   'false'),
#  ('ESL_SC2',
#   'StarCraft II',
#   'live',
#   'LIVE: Solar vs Ryung - DreamHack SC2 Masters: Atlanta 2022',
#   6157,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('awsonair',
#   'Just Chatting',
#   'live',
#   'AWS On Air - Getting Ready for re:Invent',
#   6123,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('TisiSchubech',
#   'FIFA 23',
#   'live',
#   'WM HERO TEAM 2 Pack Opening +  Weekend League Start 🔥 | !levlup !displate',
#   6094,
#   datetime.date(2022, 11, 18),
#   'de',
#   'false'),
#  ('BarcaGamer',
#   'Just Chatting',
#   'live',
#   'Estamos listos para dejar huella con Stefano en esta nueva conquista y hacer que suceda #HazQueSuceda || !Stefano',
#   6034,
#   datetime.date(2022, 11, 18),
#   'es',
#   'false'),
#  ('RTGame',
#   'Pokémon Scarlet/Violet',
#   'live',
#   '⭐I am so excited⭐ Pokemon Marathon Day 1 Starts Friday 12pm GMT',
#   6021,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('StRoGo1337',
#   'Virtual Casino',
#   'live',
#   'ПОКЛОН ИВАНУ В ЧАТЕ СРОЧНЫЙ',
#   5993,
#   datetime.date(2022, 11, 18),
#   'ru',
#   'false'),
#  ('Grubby',
#   'Dota 2',
#   'live',
#   'LEGEND TODAY? ------ [!TikTok !Xmas !NoAds]',
#   5749,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('gerardromero',
#   '',
#   'live',
#   'JIJANTESFC. REACCIONAMOS AL STREAM DE LUIS PADRIQUE. REPORTAJE DE JULI Y CARLOS POR DOHA',
#   5684,
#   datetime.date(2022, 11, 18),
#   'es',
#   'false'),
#  ('mlodziutki7',
#   'The Dark Pictures Anthology: The Devil in Me',
#   'live',
#   '😱 NOWA PRZYGODÓWA Z LUKIM GIT? GIT 😱',
#   5680,
#   datetime.date(2022, 11, 18),
#   'pl',
#   'false'),
#  ('TeePee',
#   'Call of Duty: Warzone',
#   'live',
#   'Odyssey Presents: Season of Gaming! | !samsung | #OdysseyPartner | #sponsored |',
#   5654,
#   datetime.date(2022, 11, 18),
#   'en',
#   'true'),
#  ('Carola',
#   'The Dark Pictures Anthology: The Devil in Me',
#   'live',
#   'The Devil in Me',
#   5576,
#   datetime.date(2022, 11, 18),
#   'es',
#   'false'),
#  ('CCT_EN',
#   'Counter-Strike: Global Offensive',
#   'live',
#   'ex-Finest vs CPH Flames🔹 CCT Central Europe – Playoffs Stage 🏆 Online Series 3',
#   5544,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('xRohat',
#   'Grand Theft Auto V',
#   'live',
#   '[HopeV] YOO | !IG !Socials !VOD !GamersOnly !Grand | #Werbung',
#   5496,
#   datetime.date(2022, 11, 18),
#   'de',
#   'false'),
#  ('iiTzTimmy',
#   'Overwatch 2',
#   'live',
#   'DPS DPS DPS DPS DPS DPS DPS !Overwatch Overwatch2_Sponsored / Follow my socials @iiTzTimmy',
#   5479,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('CriticalRole',
#   'Dungeons & Dragons',
#   'live',
#   'The Mighty Nein Reunited Part 1 Rebroadcast (11/18 at 9am PDT)',
#   5465,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('HisWattson',
#   'Apex Legends',
#   'live',
#   'Going for Rank #1 | ALGS MVP | !Coaching !Bats !Settings !Voltaic !Youtube | Twitter: @HisWattson',
#   5457,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('RocKy_',
#   'FIFA 23',
#   'live',
#   'FUTCHAMPIONS AVEC LA MEILLEURE EQUIPE DU JEU !',
#   5300,
#   datetime.date(2022, 11, 18),
#   'fr',
#   'false'),
#  ('Vinesauce',
#   'Pokémon Scarlet/Violet',
#   'live',
#   'Pokemon Violent + Clown Vomit Corruption Reaction',
#   5293,
#   datetime.date(2022, 11, 18),
#   'en',
#   'true'),
#  ('skill4ltu',
#   'World of Tanks',
#   'live',
#   '💥*NEW*  !DROPS 💥Good day long stream. 12-13 hours. marking charioteer starting 37% goal is 3rd mark at least. !pugs !chair',
#   5210,
#   datetime.date(2022, 11, 18),
#   'en',
#   'true'),
#  ('RebirthzTV',
#   'Dota 2',
#   'live',
#   'ตู้ โอคอนเนอร์ SS1 Classic 1.0  Omnuay',
#   5181,
#   datetime.date(2022, 11, 18),
#   'th',
#   'false'),
#  ('stak4drake',
#   'WWE 2K22',
#   'live',
#   'Massive collaborative GlVEAWAY!🎁 | Details below | 18+ #ad',
#   5013,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('Clix',
#   'Fortnite',
#   'live',
#   "Zero Build w/ Tfue & Zemie - Checking out LG's Black Friday Deals with Chat Soon! | !lgultragear !event #ad",
#   4977,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('dyrachyo',
#   'Dota 2',
#   'live',
#   '11k mmr 0 iq. rank 20(40) я схожу с ума АРК ВАРДЕНА НЕ БУДЕТ) !tg !inst',
#   4946,
#   datetime.date(2022, 11, 18),
#   'ru',
#   'false'),
#  ('winline_eml',
#   'Counter-Strike: Global Offensive',
#   'live',
#   'Winline EML: DIG BICKS 1:0 BRAVE | bo2 | Group Stage - Day 3 | by CrystalMay & Smile',
#   4946,
#   datetime.date(2022, 11, 18),
#   'ru',
#   'false'),
#  ('Philza',
#   'The Legend of Zelda: Breath of the Wild',
#   'live',
#   'MASTER MODE BOTW - 2/4 divine beasts down! (Part 3) - NEW MERCH AVAILABLE AT Ph1LzAMerch.com',
#   4590,
#   datetime.date(2022, 11, 18),
#   'en',
#   'true'),
#  ('Fakturka',
#   'Albion Online',
#   'live',
#   '🔴Drops+🔴!thread about frost shot🔴Current TOP 1 PVP fame player🔴12 Hours stream🔴Full chill !yt RUS/ENG',
#   4588,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('ZanoXVII',
#   'FIFA 23',
#   'live',
#   'WEEKEND LEAGUE BELLA DEEP DOPO POKEMON !PRIME !SUB !CAM',
#   4576,
#   datetime.date(2022, 11, 18),
#   'it',
#   'false'),
#  ('ungespielt',
#   'World of Warcraft',
#   'live',
#   'DROPS AKTIV! - !Subathon - #ungeklickt & WoW !Drops',
#   4506,
#   datetime.date(2022, 11, 18),
#   'de',
#   'false'),
#  ('Cydonia_Chiara',
#   'Pokémon Scarlet/Violet',
#   'live',
#   'BLIND RUN Pokémon Scarlatto e Violetto #2: "Mesapoli" - !SIP !nordvpn !prime',
#   4495,
#   datetime.date(2022, 11, 18),
#   'it',
#   'false'),
#  ('Ray',
#   'Pokémon Scarlet/Violet',
#   'live',
#   '!giveaway !store | POKEMON SCARLET/VIOLET IS HERE!!!',
#   4494,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false'),
#  ('VooDooSh',
#   'The Dark Pictures Anthology: The Devil in Me',
#   'live',
#   'Новый Кино-Хоррор от Dark Pictures! The Devil in Me! Заходи!',
#   4442,
#   datetime.date(2022, 11, 18),
#   'ru',
#   'false'),
#  ('akaNemsko',
#   'Just Chatting',
#   'live',
#   '!FLEX FRIDAY ~ come flex your games | !socials !100K',
#   4427,
#   datetime.date(2022, 11, 18),
#   'en',
#   'false')]
